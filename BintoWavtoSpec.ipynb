# %%
# import base64
file_path = 'C:\\Drivers\\Bluetooth\\Source\\mtkbtfilterx.sys'
# with open(file_path, "rb") as contents:
#     converted_string = base64.b64encode(contents.read())
#     print(converted_string)

# %%
impath = 'C:\\Users\\genem\\Documents\\MSDS\\DE_IMG_Wk\\imgs\\7z.exe.png'
# make_wav(impath)

# %%
# !pip install pydub

# %%
#run this to create a wav
#python sp.py C:\Users\genem\Documents\MSDS\DE_IMG_Wk\imgs\7z.exe.png 7z.wav

# %%
import os
import wave

import pylab
def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

# %%
graph_spectrogram('7z.wav')
# Out:
# C:\Users\genem\AppData\Local\Temp\ipykernel_37836\4107925338.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   sound_info = pylab.fromstring(frames, 'int16')
# C:\Users\genem\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:7773: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# # Reference
# https://www.hackster.io/sam1902/encode-image-in-sound-with-python-f46a3f
